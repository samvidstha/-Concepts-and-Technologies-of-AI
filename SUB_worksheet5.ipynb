# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Concept And Technology Of AI/Houseprice (1).csv')
df.head()
# Out:
#    HouseAge  HouseFloor   HouseArea     HousePrice
# 0        52           2  112.945574  543917.179841
# 1        93           1  174.312126  817740.124828
# 2        15           4  125.219577  387992.503019
# 3        72           4  121.210124  240840.742388
# 4        61           4   59.221737  277273.386525

# %%
house_age=df['HouseAge'].to_numpy()
house_floor=df['HouseFloor'].to_numpy()
house_area = df['HouseArea'].to_numpy()
house_price=df['HousePrice'].to_numpy()

# %%
x0=np.ones(len(house_age))
X2=np.array([x0,house_age,house_floor,house_area]).T
W=np.array([0,0,0,0])
Y2=np.array(house_price)

# %%
def cost_function(X,Y,W):
  """
  Finds the mean square error.
  Input:
    X=Feature Matrix
    Y=Target Vector
    W=Weith Vector
  Output:
    J=Mean Square Error
  """
  m=len(Y)
  J=np.sum((X.dot(W)-Y)**2)/(2*m)
  return J

# %%
X_test=np.array([[1,2],[3,4],[5,6]])
Y_test=np.array([1,2,3])
W_test=np.array([1,2])
cost=cost_function(X_test,Y_test,W_test)
if cost==0:
  print('Proceed Further')
else:
  print('Something went wrong: Reimplement the cost function')
  print('Cost function output: ',cost)
# Out:
# Something went wrong: Reimplement the cost function
# Cost function output:  48.833333333333336

# %%
initial_cost=cost_function(X2,Y2,W)
print('Initial Cost: ',initial_cost)
# Out:
# Initial Cost:  201528080199.132

# %%
def gradient_descent(X, Y, W, alpha, iterations):
    cost_history = [0] * iterations
    m = len(Y)

    for iteration in range(iterations):
        Y_pred = X.dot(W)
        loss = Y_pred - Y
        dw = (X.T.dot(loss)) / m
        W = W - alpha * dw
        cost = cost_function(X, Y, W)
        cost_history[iteration] = cost
    return W, cost_history

# %%
alpha=0.00000001
new_weight,cost_history=gradient_descent(X2,Y2,W,alpha,10000)
print("Final Weight: ",new_weight)
print("Final Cost: ",cost_history[-1])
# Out:
# Final Weight:  [  15.90207926  740.48937055   41.80987388 3058.96694575]
# Final Cost:  12326103795.093918

# %%
def rmse(Y,Y_pred):
  """
  This Function calculates the Root Mean Squres.
  Input Arguments:
    Y: Array of actual(Target) Dependent Varaibles.
    Y_pred: Array of predeicted Dependent Varaibles.
  Output Arguments:
    rmse: Root Mean Square.
  """
  rmse=np.sqrt(sum((Y-Y_pred)**2)/len(Y))
  return rmse

# %%
def r2(Y,Y_pred):
    """
  This Function calculates the Root Mean Squres.
  Input Arguments:
    Y: Array of actual(Target) Dependent Varaibles.
    Y_pred: Array of predeicted Dependent Varaibles.
  Output Arguments:
    rmse: Root Mean Square.
  """
    mean_y=np.mean(Y)
    ss_tot=sum((Y-mean_y)**2)
    ss_res=sum((Y-Y_pred)**2)
    r2=1-(ss_res/ss_tot)
    return r2

# %%
Y_pred=X2.dot(new_weight)
print("RMSE: ",rmse(Y2,Y_pred))
print("R2 Score: ",r2(Y2,Y_pred))
# Out:
# RMSE:  157010.21492306745
# R2 Score:  0.6358796809297357
